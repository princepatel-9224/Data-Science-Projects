# %%
#import librarys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
Computer_Data=pd.read_csv("E:\\Assignments\\multi linear reggresion\\Computer_Data.csv")

# %%
Computer_Data.head(10)
# Out:
#    Unnamed: 0  price  speed   hd  ram  screen   cd multi premium  ads  trend
# 0           1   1499     25   80    4      14   no    no     yes   94      1
# 1           2   1795     33   85    2      14   no    no     yes   94      1
# 2           3   1595     25  170    4      15   no    no     yes   94      1
# 3           4   1849     25  170    8      14   no    no      no   94      1
# 4           5   3295     33  340   16      14   no    no     yes   94      1
# 5           6   3695     66  340   16      14   no    no     yes   94      1
# 6           7   1720     25  170    4      14  yes    no     yes   94      1
# 7           8   1995     50   85    2      14   no    no     yes   94      1
# 8           9   2225     50  210    8      14   no    no     yes   94      1
# 9          10   2575     50  210    4      15   no    no     yes   94      1

# %%
Computer_Data = Computer_Data.drop("Unnamed: 0", axis=1) ### delete count columns

# %%
Computer_Data.head(10)
# Out:
#    price  speed   hd  ram  screen   cd multi premium  ads  trend
# 0   1499     25   80    4      14   no    no     yes   94      1
# 1   1795     33   85    2      14   no    no     yes   94      1
# 2   1595     25  170    4      15   no    no     yes   94      1
# 3   1849     25  170    8      14   no    no      no   94      1
# 4   3295     33  340   16      14   no    no     yes   94      1
# 5   3695     66  340   16      14   no    no     yes   94      1
# 6   1720     25  170    4      14  yes    no     yes   94      1
# 7   1995     50   85    2      14   no    no     yes   94      1
# 8   2225     50  210    8      14   no    no     yes   94      1
# 9   2575     50  210    4      15   no    no     yes   94      1

# %%
Computer_Data.shape
# Out:
# (6259, 10)

# %%
Computer_Data.describe()
# Out:
#              price        speed           hd          ram       screen  \
# count  6259.000000  6259.000000  6259.000000  6259.000000  6259.000000
# mean   2219.576610    52.011024   416.601694     8.286947    14.608723
# std     580.803956    21.157735   258.548445     5.631099     0.905115
# min     949.000000    25.000000    80.000000     2.000000    14.000000
# 25%    1794.000000    33.000000   214.000000     4.000000    14.000000
# 50%    2144.000000    50.000000   340.000000     8.000000    14.000000
# 75%    2595.000000    66.000000   528.000000     8.000000    15.000000
# max    5399.000000   100.000000  2100.000000    32.000000    17.000000
#
#                ads        trend
# count  6259.000000  6259.000000
# mean    221.301007    15.926985
# std      74.835284     7.873984
# min      39.000000     1.000000
# 25%     162.500000    10.000000
# 50%     246.000000    16.000000
# 75%     275.000000    21.500000
# max     339.000000    35.000000

# %%
Computer_Data.columns
# Out:
# Index(['price', 'speed', 'hd', 'ram', 'screen', 'cd', 'multi', 'premium',
#        'ads', 'trend'],
#       dtype='object')

# %%
import seaborn as sns

# %%
sns.pairplot(Computer_Data)

# %%
import statsmodels.formula.api as smf

# %%
Model1 = smf.ols('price~speed+hd+ram+screen+ads+trend',data=Computer_Data).fit()

# %%
Model1.summary() #R-squared: 0.712
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.712
# Model:                            OLS   Adj. R-squared:                  0.712
# Method:                 Least Squares   F-statistic:                     2580.
# Date:                Mon, 23 Sep 2019   Prob (F-statistic):               0.00
# Time:                        18:36:46   Log-Likelihood:                -44817.
# No. Observations:                6259   AIC:                         8.965e+04
# Df Residuals:                    6252   BIC:                         8.969e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -246.6755     66.371     -3.717      0.000    -376.785    -116.566
# ...

# %%
Model_speed=Model1 = smf.ols('price~speed',data=Computer_Data).fit()

# %%
Model_speed.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.091
# Model:                            OLS   Adj. R-squared:                  0.090
# Method:                 Least Squares   F-statistic:                     623.3
# Date:                Mon, 23 Sep 2019   Prob (F-statistic):          3.23e-131
# Time:                        19:03:36   Log-Likelihood:                -48418.
# No. Observations:                6259   AIC:                         9.684e+04
# Df Residuals:                    6257   BIC:                         9.685e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1789.8539     18.582     96.320      0.000    1753.426    1826.282
# ...

# %%
# p-value <0.05 .. It is significant

# %%
Model_hd=Model1 = smf.ols('price~hd',data=Computer_Data).fit()

# %%
Model_hd.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.185
# Model:                            OLS   Adj. R-squared:                  0.185
# Method:                 Least Squares   F-statistic:                     1421.
# Date:                Mon, 23 Sep 2019   Prob (F-statistic):          1.67e-280
# Time:                        19:03:53   Log-Likelihood:                -48075.
# No. Observations:                6259   AIC:                         9.615e+04
# Df Residuals:                    6257   BIC:                         9.617e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1816.9176     12.569    144.552      0.000    1792.277    1841.558
# ...

# %%
# p-value <0.05 .. It is significant

# %%
Model_ram=Model1 = smf.ols('price~ram',data=Computer_Data).fit()

# %%
Model_ram.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.388
# Model:                            OLS   Adj. R-squared:                  0.388
# Method:                 Least Squares   F-statistic:                     3964.
# Date:                Mon, 23 Sep 2019   Prob (F-statistic):               0.00
# Time:                        19:04:58   Log-Likelihood:                -47180.
# No. Observations:                6259   AIC:                         9.436e+04
# Df Residuals:                    6257   BIC:                         9.438e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1687.2925     10.221    165.073      0.000    1667.255    1707.330
# ...

# %%
# p-value <0.05 .. It is significant

# %%
Model_screen=Model1 = smf.ols('price~screen',data=Computer_Data).fit()

# %%
Model_screen.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.088
# Model:                            OLS   Adj. R-squared:                  0.087
# Method:                 Least Squares   F-statistic:                     601.0
# Date:                Mon, 23 Sep 2019   Prob (F-statistic):          8.15e-127
# Time:                        19:06:10   Log-Likelihood:                -48428.
# No. Observations:                6259   AIC:                         9.686e+04
# Df Residuals:                    6257   BIC:                         9.687e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -555.5993    113.415     -4.899      0.000    -777.931    -333.267
# ...

# %%
# p-value <0.05 .. It is significant

# %%
Model_ads=Model1 = smf.ols('price~ads',data=Computer_Data).fit()

# %%
Model_ads.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     18.67
# Date:                Mon, 23 Sep 2019   Prob (F-statistic):           1.58e-05
# Time:                        19:07:46   Log-Likelihood:                -48706.
# No. Observations:                6259   AIC:                         9.742e+04
# Df Residuals:                    6257   BIC:                         9.743e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2125.9012     22.887     92.888      0.000    2081.035    2170.767
# ...

# %%
# p-value <0.05 .. It is significant

# %%
Model_trend=Model1 = smf.ols('price~trend',data=Computer_Data).fit()

# %%
Model_trend.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.040
# Method:                 Least Squares   F-statistic:                     260.7
# Date:                Mon, 23 Sep 2019   Prob (F-statistic):           1.75e-57
# Time:                        19:08:31   Log-Likelihood:                -48588.
# No. Observations:                6259   AIC:                         9.718e+04
# Df Residuals:                    6257   BIC:                         9.719e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2454.5238     16.233    151.206      0.000    2422.702    2486.346
# ...

# %%
# p-value <0.05 .. It is significant

# %%
Log_price=np.log(Computer_Data.price)

# %%
Model_log = smf.ols('Log_price~speed+hd+ram+screen+ads+trend',data=Computer_Data).fit()

# %%
Model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              New_price   R-squared:                       0.716
# Model:                            OLS   Adj. R-squared:                  0.716
# Method:                 Least Squares   F-statistic:                     2632.
# Date:                Mon, 23 Sep 2019   Prob (F-statistic):               0.00
# Time:                        19:22:29   Log-Likelihood:                 3542.4
# No. Observations:                6259   AIC:                            -7071.
# Df Residuals:                    6252   BIC:                            -7024.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      6.5808      0.029    224.799      0.000       6.523       6.638
# ...

# %%
Sqrt_price=np.sqrt(Computer_Data.price)

# %%
Model_sqrt = smf.ols('Sqrt_price~speed+hd+ram+screen+ads+trend',data=Computer_Data).fit()

# %%
Model_sqrt.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             Sqrt_price   R-squared:                       0.720
# Model:                            OLS   Adj. R-squared:                  0.720
# Method:                 Least Squares   F-statistic:                     2683.
# Date:                Mon, 23 Sep 2019   Prob (F-statistic):               0.00
# Time:                        19:25:16   Log-Likelihood:                -16165.
# No. Observations:                6259   AIC:                         3.234e+04
# Df Residuals:                    6252   BIC:                         3.239e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     20.9958      0.682     30.777      0.000      19.658      22.333
# ...

# %%
Pred_sqrt=Model_sqrt.predict(Computer_Data[['speed','hd','ram','screen','ads','trend']])

# %%
Pred_sqrt.head(20)
# Out:
# 0     44.822483
# 1     44.622908
# 2     46.803118
# 3     47.473458
# 4     53.458184
# 5     56.579288
# 6     45.487190
# 7     46.230750
# 8     50.133356
# 9     49.463016
# 10    49.546017
# 11    51.646619
# 12    47.556237
# 13    48.027380
# 14    50.148128
# 15    47.556237
# 16    44.622908
# 17    47.855174
# 18    48.150600
# 19    53.433942
# dtype: float64

# %%
Final_pred=Pred_sqrt*Pred_sqrt

# %%
Final_pred.head(20)
# Out:
# 0     2009.054953
# 1     1991.203919
# 2     2190.531823
# 3     2253.729212
# 4     2857.777398
# 5     3201.215840
# 6     2069.084415
# 7     2137.282217
# 8     2513.353416
# 9     2446.589953
# 10    2454.807845
# 11    2667.373263
# 12    2261.595710
# 13    2306.629267
# 14    2514.834701
# 15    2261.595710
# 16    1991.203919
# 17    2290.117710
# 18    2318.480244
# 19    2855.186167
# dtype: float64

# %%
rsq_speed = smf.ols('speed~ram+hd+screen+ads+trend',data=Computer_Data).fit().rsquared  

vif_speed = 1/(1-rsq_speed)

vif_speed  ####1.257595278566506
# Out:
# 1.257595278566506

# %%
rsq_ram = smf.ols('ram~speed+hd+screen+ads+trend',data=Computer_Data).fit().rsquared

# %%
vif_ram = 1/(1-rsq_ram)

# %%
vif_ram  ####2.8814231450591254
# Out:
# 2.8814231450591254

# %%
rsq_hd = smf.ols('hd~speed+ram+screen+ads+trend',data=Computer_Data).fit().rsquared

# %%
vif_hd = 1/(1-rsq_hd)

# %%
vif_hd   ####4.114441163120937
# Out:
# 4.114441163120937

# %%
rsq_screen = smf.ols('screen~speed+ram+hd+ads+trend',data=Computer_Data).fit().rsquared

# %%
vif_screen = 1/(1-rsq_screen)

# %%
vif_screen ###1.0789293881863944
# Out:
# 1.0789293881863944

# %%
rsq_ads = smf.ols('ads~speed+ram+hd+screen+trend',data=Computer_Data).fit().rsquared

# %%
vif_ads = 1/(1-rsq_ads)

# %%
vif_ads  ###1.1603365223193798
# Out:
# 1.1603365223193798

# %%
rsq_trend = smf.ols('trend~speed+ram+hd+screen+ads',data=Computer_Data).fit().rsquared

# %%
vif_trend = 1/(1-rsq_trend)

# %%
vif_trend  ####1.82454173949135
# Out:
# 1.82454173949135

# %%
d1 = {'Variables':['speed','ram','hd','screen','ads','trend'],'VIF':[vif_speed,vif_ram,vif_hd,vif_screen,vif_ads,vif_trend]}

# %%
Vif_frame = pd.DataFrame(d1)  
Vif_frame
# Out:
#   Variables       VIF
# 0     speed  1.257595
# 1       ram  2.881423
# 2        hd  4.114441
# 3    screen  1.078929
# 4       ads  1.160337
# 5     trend  1.824542

# %%
import statsmodels.api as sm

# %%
fig = plt.figure(figsize=(15,12))
sm.graphics.plot_partregress_grid(Model_sqrt,fig=fig)

# %%
plt.scatter(Computer_Data.price,Final_pred,c="r")
plt.xlabel("observed_values")
plt.ylabel("fitted_values")
# Out:
# Text(0, 0.5, 'fitted_values')

# %%
plt.scatter(Final_pred,Model_sqrt.resid_pearson,c="r"),plt.axhline(y=0,color='blue')
plt.xlabel("fitted_values")
plt.ylabel("residuals")
# Out:
# Text(0, 0.5, 'residuals')
